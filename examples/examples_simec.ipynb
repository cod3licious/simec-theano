# %% [markdown]
# # Experiments with Similarity Encoders
# In this iPython Notebook are some examples to illustrate the potential of Similarity Encoders (SimEc) for creating similarity preserving embeddings. For further details and theoretical background on this new neural network architecture, please refer to [the corresponding paper](http://arxiv.org/abs/1702.01824).
#
# The notebook is structured as follows: After a short toy example, we present several experiments performed on the sklearn handwritten digits dataset (a small real world dataset which works great to quickly test some things out). Then we present the results on the MNIST and 20 newsgroups datasets reported in the original paper.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.distance import pdist, squareform
import theano.tensor as T
from sklearn.metrics.pairwise import rbf_kernel
from sklearn.manifold import Isomap, TSNE
from sklearn.decomposition import PCA, KernelPCA
from sklearn.datasets import load_digits, fetch_mldata, fetch_20newsgroups

# find nlputils at https://github.com/cod3licious/nlputils
from nlputils.features import FeatureTransform, features2mat

from utils import load_dataset, plot2d, plot3d, plot_digits, plot_mnist, plot_20news, check_embed_match
from simec.similarity_encoder import SimilarityEncoder, center_K, scaled_sigmoid
from simec.ann_models import SupervisedNNModel

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Toy Dataset: 3 Circles
# Sanity check on an artificially generated toy dataset: Linear similarity encoders reach the same solution as PCA/linear kPCA (up to a rotation and scaling) and nicely map the test examples where they belong.

# %%
n_train = 1000
n_test = 500
dataset = '3_circles'
# get training and test data
X, Y_plot = load_dataset(dataset, n_train, 3)
X_test, Y_plot_test = load_dataset(dataset, n_test, 5)
# plot the original data
plot3d(X, Y_plot, X_test, Y_plot_test, title='%s dataset' % dataset.replace('_', ' '))

# %%
# simple 2D PCA solution
e_pca = PCA(n_components=2)
X_embed = e_pca.fit_transform(X)
X_embed_test = e_pca.transform(X_test)
plot2d(X_embed, Y_plot, X_embed_test, Y_plot_test, 
       title='%s embedded with PCA' % dataset.replace('_', ' '))

# %%
# similarity encoder no activation function, linear similarities as targets
K_lin = np.dot(X, X.T)
e_lsimenc = SimilarityEncoder(K_lin.shape[1], X.shape[1], e_dim=2, lrate=1.)
e_lsimenc.fit(X, K_lin, verbose=False)
X_embeds = e_lsimenc.transform(X)
X_embed_tests = e_lsimenc.transform(X_test)
plot2d(X_embeds, Y_plot, X_embed_tests, Y_plot_test, 
       title='%s embedded with a linear similarity encoder' % dataset.replace('_', ' '))
print "correlation with PCA: %f" % check_embed_match(X_embed, X_embeds)
print "correlation with PCA (test): %f" % check_embed_match(X_embed_test, X_embed_tests)
# Out:
# Final training error after 5000 epochs: 0.0123913813; lowest error: 0.0123913813
# Last mean error: 0.0123911359
# correlation with PCA: 0.990878
# correlation with PCA (test): 0.990586

# %% [markdown]
# ## Handwritten Digits (8x8 px)
# See `http://scikit-learn.org/stable/auto_examples/datasets/plot_digits_last_image.html`

# %%
# load digits dataset
digits = load_digits()
X = digits.data
X /= float(X.max())
y = digits.target
n_samples, n_features = X.shape

# %% [markdown]
# #### Linear kernel PCA
# A linear SimEc gets the same solution as PCA (= linear kernel PCA) up to a rotation

# %%
# PCA
e_pca = PCA(n_components=2)
X_embedp = e_pca.fit_transform(X)
plot_digits(X_embedp, digits, title='Digits embedded with PCA')

# %%
# linear kPCA - same as regular PCA...;)
e_lkpca = KernelPCA(n_components=2, kernel='linear')
X_embed = e_lkpca.fit_transform(X)
plot_digits(X_embed, digits, title='Digits embedded with linear Kernel PCA')
print "correlation of PCA and linear kPCA: %f" % check_embed_match(X_embed, X_embedp)
# Out:
# correlation of PCA and linear kPCA: 1.000000

# %%
# linear similarity encoder (center the kernel matrix first!)
K_lin = np.dot(X, X.T)
e_lsimenc = SimilarityEncoder(K_lin.shape[1], X.shape[1], e_dim=2, lrate=1.)
e_lsimenc.fit(X, center_K(K_lin), verbose=False)
X_embeds = e_lsimenc.transform(X)
plot_digits(X_embeds, digits, title='Digits embedded with a linear similarity encoder')
print "correlation with linear kPCA: %f" % check_embed_match(X_embed, X_embeds)
# Out:
# Final training error after 1246 epochs: 0.0095659069; lowest error: 0.0095659069
# Last mean error: 0.0095646933
# correlation with linear kPCA: 0.999793

# %% [markdown]
# #### Non-linear spectral methods
# Linear kPCA is straight forward, but what if we use a non-linear kernel function like the Gaussian kernel or isomap?
# For the corresponding SimEcs we add some non-linear hidden layers.

# %%
# Gaussian kernel PCA
D = squareform(pdist(X, 'euclidean'))
gamma = 1./(np.median(D)**2)    
e_gkpca = KernelPCA(n_components=2, kernel='rbf', gamma=gamma)
X_embed = e_gkpca.fit_transform(X)
plot_digits(X_embed, digits, title='Digits embedded with Gaussian Kernel PCA')

# %%
# non-linear SimEc with rbf kernel
K_rbf = rbf_kernel(X, X, gamma)
e_gsimenc = SimilarityEncoder(K_rbf.shape[1], X.shape[1], 2, [40], [T.tanh, None, None], lrate=2.)
e_gsimenc.fit(X, center_K(K_rbf), verbose=False)
X_embeds = e_gsimenc.transform(X)
plot_digits(X_embeds, digits, title='Digits - SimEc (rbf kernel, 1 h.l.)')
print "correlation with Gaussian kPCA: %f" % check_embed_match(X_embed, X_embeds)
# Out:
# Final training error after 5000 epochs: 0.0079553613; lowest error: 0.0079553613
# Last mean error: 0.0079532833
# correlation with Gaussian kPCA: 0.997451

# %%
# isomap
e_isomap = Isomap(n_neighbors=10, n_components=2)
X_embed = e_isomap.fit_transform(X)
plot_digits(X_embed, digits, title='Digits embedded with isomap')

# %%
# non-linear SimEc based on isomap
K_geod = e_isomap.dist_matrix_
e_gsimenc = SimilarityEncoder(K_geod.shape[1], X.shape[1], 2, [40], [T.tanh, None, None], 
                              lrate=2.)
e_gsimenc.fit(X, center_K(K_geod), verbose=False)
X_embeds = e_gsimenc.transform(X)
plot_digits(X_embeds, digits, title='Digits - SimEc (geodesic, 1 h.l.)')
print "correlation with isomap: %f" % check_embed_match(X_embed, X_embeds)
# Out:
# Final training error after 5000 epochs: 0.0125362571; lowest error: 0.0125362571
# Last mean error: 0.0125370728
# correlation with isomap: 0.969294

# %%
# non-linear SimEc based on isomap - 2 hidden layers
K_geod = e_isomap.dist_matrix_
e_gsimenc = SimilarityEncoder(K_geod.shape[1], X.shape[1], 2, [40, 20], [T.tanh, T.tanh, None, None], 
                              lrate=2.)
e_gsimenc.fit(X, center_K(K_geod), verbose=False)
X_embeds = e_gsimenc.transform(X)
plot_digits(X_embeds, digits, title='Digits - SimEc (geodesic, 2 h.l.)')
print "correlation with isomap: %f" % check_embed_match(X_embed, X_embeds)
# Out:
# Final training error after 5000 epochs: 0.0124591451; lowest error: 0.0124591451
# Last mean error: 0.0124564640
# correlation with isomap: 0.969892

# %% [markdown]
# #### t-SNE
# A visualization like that created with t-SNE might look better. (But do you notice those few examples trapped between the clusters? This happens because the embedding coordinates are optimized directly instead of learning a mapping function.) - we're not there yet with SimEcs, this calls for better similarity matrices, maybe different non-linearities...

# %%
# t-SNE
e_tsne = TSNE(n_components=2, random_state=1, method='exact')
X_embed = e_tsne.fit_transform(X)
plot_digits(X_embed, digits, title='Digits embedded with t-SNE')

# %% [markdown]
# #### SimEc based on class labels
# We've seen that SimEcs can reach the same solutions as traditional spectral methods such as kPCA and isomap. However, these methods have the limitation that you can only embed new data points if you can compute their kernel map, i.e. the similarity to the training examples. But what if the similarity matrix used as targets during training was generated by an unknown process such as human similarity judgments? KPCA will probably fail completely since it requires a positive semi-definite kernel function... But we can still use SimEcs!
#
# To show this, we construct the similarity matrix from the class labels assigned by human annotators (1=same class, 0=different class).

# %%
Y = np.tile(y, (len(y), 1))
S = np.array(Y==Y.T, dtype=int)

# %% [markdown]
# Lets first try a simple linear SimEc.

# %%
# similarity encoder with similarities relying on class information - linear
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [], [None, None], lrate=5., L2_reg=0.0001)
e_csimenc.fit(X, S, verbose=False)
X_embed = e_csimenc.transform(X)
plot_digits(X_embed, digits, title='Digits - SimEc (class sim, linear)')
# Out:
# Final training error after 795 epochs: 0.0733289987; lowest error: 0.0733289021
# Last mean error: 0.0733397850

# %% [markdown]
# Well, this is very similar to the original linear SimEc that did not make use of class labels, so this is kind of disappointing. Here we didn't center the similarity matrix - might that help?

# %%
# similarity encoder with similarities relying on class information - linear; center S
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [], [None, None], lrate=5., L2_reg=0.0001)
e_csimenc.fit(X, center_K(S), verbose=False)
X_embed = e_csimenc.transform(X)
plot_digits(X_embed, digits, title='Digits - SimEc (class sim (centered), linear)')
# Out:
# Final training error after 1329 epochs: 0.0892253436; lowest error: 0.0892204955
# Last mean error: 0.0892481065

# %% [markdown]
# Nope. But we know the target similarities are either 0 or 1, so we could make use of this information and apply a thresholding function to our output to optimize the results. More concrete: we don't center S but map the output almost linearly between 0 and 1 while fixing it to 0 or 1 outside this interval.

# %%
# similarity encoder with similarities relying on class information - linear
# no centering of S but instead a thresholding in the last layer 
# to transform the output to be between 0 and 1
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [], [None, scaled_sigmoid], 
                              lrate=5., L2_reg=0.0001)
e_csimenc.fit(X, S, verbose=False)
X_embed = e_csimenc.transform(X)
plot_digits(X_embed, digits, title='Digits - SimEc (class sim, linear with threshold)')
# Out:
# Final training error after 5000 epochs: 0.0551330481; lowest error: 0.0551330481
# Last mean error: 0.0551138174

# %% [markdown]
# Great, we already see some clusters separating from the rest! What if we add more layers?

# %%
# similarity encoder with similarities relying on class information - 1 hidden layer
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [20], [T.tanh, None, scaled_sigmoid],
                              lrate=10., L2_reg=0.000005)
e_csimenc.fit(X, center_K(S), verbose=True)
X_embed = e_csimenc.transform(X)
plot_digits(X_embed, digits, title='Digits - SimEc (class sim, 1 h.l.)', plot_box=False)
# Out:
# Epoch 1
# Mean training error: 0.1096162581
# Epoch 25
# Mean training error: 0.1096139962
# Epoch 50
# Mean training error: 0.1096116393
# Epoch 75
# Mean training error: 0.1096087388
# Epoch 100
# Mean training error: 0.1096041500
# Epoch 125
# Mean training error: 0.1095942511
# Epoch 150
# Mean training error: 0.1095590188
# Epoch 175
# Mean training error: 0.0988977929
# Epoch 200
# Mean training error: 0.0899402888
# Epoch 225
# Mean training error: 0.0737812542
# Epoch 250
# Mean training error: 0.0719024861
# Epoch 275
# Mean training error: 0.0712146626
# Epoch 300
# Mean training error: 0.0709205900
# Epoch 325
# Mean training error: 0.0707517719
# Epoch 350
# Mean training error: 0.0706042913
# Epoch 375
# Mean training error: 0.0705204912
# Epoch 400
# Mean training error: 0.0704542560
# Epoch 425
# Mean training error: 0.0704167067
# Epoch 450
# Mean training error: 0.0703883692
# Epoch 475
# Mean training error: 0.0703509231
# Epoch 500
# Mean training error: 0.0702933363
# Epoch 525
# Mean training error: 0.0702687287
# Epoch 550
# Mean training error: 0.0702523239
# Epoch 575
# Mean training error: 0.0702401095
# Epoch 600
# Mean training error: 0.0702304453
# Epoch 625
# Mean training error: 0.0702224738
# Epoch 650
# Mean training error: 0.0702156977
# Epoch 675
# Mean training error: 0.0702098079
# Epoch 700
# Mean training error: 0.0702046012
# Epoch 725
# Mean training error: 0.0701999369
# Epoch 750
# Mean training error: 0.0701957141
# Epoch 775
# Mean training error: 0.0701918580
# Epoch 800
# Mean training error: 0.0701883118
# Epoch 825
# Mean training error: 0.0701850318
# Epoch 850
# Mean training error: 0.0701819836
# Epoch 875
# Mean training error: 0.0701791395
# Epoch 900
# Mean training error: 0.0701764771
# Epoch 925
# Mean training error: 0.0701739772
# Epoch 950
# Mean training error: 0.0701716235
# Epoch 975
# Mean training error: 0.0701694015
# Epoch 1000
# Mean training error: 0.0701672985
# Epoch 1025
# Mean training error: 0.0701653027
# Epoch 1050
# Mean training error: 0.0701634042
# Epoch 1075
# Mean training error: 0.0701615938
# Epoch 1100
# Mean training error: 0.0701598639
# Epoch 1125
# Mean training error: 0.0701582077
# Epoch 1150
# Mean training error: 0.0701566193
# Epoch 1175
# Mean training error: 0.0701550937
# Epoch 1200
# Mean training error: 0.0701536266
# Epoch 1225
# Mean training error: 0.0701522140
# Epoch 1250
# Mean training error: 0.0701508524
# Epoch 1275
# Mean training error: 0.0701495389
# Epoch 1300
# Mean training error: 0.0701482706
# Epoch 1325
# Mean training error: 0.0701470451
# Epoch 1350
# Mean training error: 0.0701458599
# Epoch 1375
# Mean training error: 0.0701447130
# Epoch 1400
# Mean training error: 0.0701436021
# Epoch 1425
# Mean training error: 0.0701425255
# Epoch 1450
# Mean training error: 0.0701414811
# Epoch 1475
# Mean training error: 0.0701404672
# Epoch 1500
# Mean training error: 0.0701394818
# Epoch 1525
# Mean training error: 0.0701385233
# Epoch 1550
# Mean training error: 0.0701375899
# Epoch 1575
# Mean training error: 0.0701366799
# Epoch 1600
# Mean training error: 0.0701357918
# Epoch 1625
# Mean training error: 0.0701349238
# Epoch 1650
# Mean training error: 0.0701340745
# Epoch 1675
# Mean training error: 0.0701332424
# Epoch 1700
# Mean training error: 0.0701324260
# Epoch 1725
# Mean training error: 0.0701316240
# Epoch 1750
# Mean training error: 0.0701308349
# Epoch 1775
# Mean training error: 0.0701300574
# Epoch 1800
# Mean training error: 0.0701292902
# Epoch 1825
# Mean training error: 0.0701285317
# Epoch 1850
# Mean training error: 0.0701277807
# Epoch 1875
# Mean training error: 0.0701270356
# Epoch 1900
# Mean training error: 0.0701262948
# Epoch 1925
# Mean training error: 0.0701255565
# Epoch 1950
# Mean training error: 0.0701248188
# Epoch 1975
# Mean training error: 0.0701240796
# Epoch 2000
# Mean training error: 0.0701233363
# Epoch 2025
# Mean training error: 0.0701225862
# Epoch 2050
# Mean training error: 0.0701218260
# Epoch 2075
# Mean training error: 0.0701210518
# Epoch 2100
# Mean training error: 0.0701202589
# Epoch 2125
# Mean training error: 0.0701194418
# Epoch 2150
# Mean training error: 0.0701185936
# Epoch 2175
# Mean training error: 0.0701177055
# Epoch 2200
# Mean training error: 0.0701167662
# Epoch 2225
# Mean training error: 0.0701157613
# Epoch 2250
# Mean training error: 0.0701146709
# Epoch 2275
# Mean training error: 0.0701134674
# Epoch 2300
# Mean training error: 0.0701121113
# Epoch 2325
# Mean training error: 0.0701105426
# Epoch 2350
# Mean training error: 0.0701086653
# Epoch 2375
# Mean training error: 0.0701063137
# Epoch 2400
# Mean training error: 0.0701031683
# Epoch 2425
# Mean training error: 0.0700985024
# Epoch 2450
# Mean training error: 0.0700900831
# Epoch 2475
# Mean training error: 0.0700626773
# Epoch 2500
# Mean training error: 0.0701563312
# Learning rate too high! Reseting to best local minima (error: 0.0699815046).
# Sanity check, mean test error: 0.0701281745
# Epoch 2525
# Mean training error: 0.0625496608
# Epoch 2550
# Mean training error: 0.0615360143
# Epoch 2575
# Mean training error: 0.0611630858
# Epoch 2600
# Mean training error: 0.0609088297
# Epoch 2625
# Mean training error: 0.0607212677
# Epoch 2650
# Mean training error: 0.0606300172
# Epoch 2675
# Mean training error: 0.0605716460
# Epoch 2700
# Mean training error: 0.0605306325
# Epoch 2725
# Mean training error: 0.0605002173
# Epoch 2750
# Mean training error: 0.0604767739
# Epoch 2775
# Mean training error: 0.0604581476
# Epoch 2800
# Mean training error: 0.0604429720
# Epoch 2825
# Mean training error: 0.0604303365
# Epoch 2850
# Mean training error: 0.0604196070
# Epoch 2875
# Mean training error: 0.0604103203
# Epoch 2900
# Mean training error: 0.0604021057
# Epoch 2925
# Mean training error: 0.0603945903
# Epoch 2950
# Mean training error: 0.0603872509
# Epoch 2975
# Mean training error: 0.0603645026
# Epoch 3000
# Mean training error: 0.0603350513
# Epoch 3025
# Mean training error: 0.0603267017
# Epoch 3050
# Mean training error: 0.0603206303
# Epoch 3075
# Mean training error: 0.0603155918
# Epoch 3100
# Mean training error: 0.0603112084
# Epoch 3125
# Mean training error: 0.0603072975
# Epoch 3150
# Mean training error: 0.0603037512
# Epoch 3175
# Mean training error: 0.0603004980
# Epoch 3200
# Mean training error: 0.0602974875
# Epoch 3225
# Mean training error: 0.0602946819
# Epoch 3250
# Mean training error: 0.0602920524
# Epoch 3275
# Mean training error: 0.0602895762
# Epoch 3300
# Mean training error: 0.0602872346
# Epoch 3325
# Mean training error: 0.0602850127
# Epoch 3350
# Mean training error: 0.0602828976
# Epoch 3375
# Mean training error: 0.0602808788
# Epoch 3400
# Mean training error: 0.0602789471
# Epoch 3425
# Mean training error: 0.0602770947
# Epoch 3450
# Mean training error: 0.0602753148
# Epoch 3475
# Mean training error: 0.0602736013
# Epoch 3500
# Mean training error: 0.0602719491
# Epoch 3525
# Mean training error: 0.0602703535
# Epoch 3550
# Mean training error: 0.0602688103
# Epoch 3575
# Mean training error: 0.0602673158
# Epoch 3600
# Mean training error: 0.0602658667
# Epoch 3625
# Mean training error: 0.0602644599
# Epoch 3650
# Mean training error: 0.0602630927
# Epoch 3675
# Mean training error: 0.0602617625
# Epoch 3700
# Mean training error: 0.0602604670
# Epoch 3725
# Mean training error: 0.0602592042
# Epoch 3750
# Mean training error: 0.0602579719
# Epoch 3775
# Mean training error: 0.0602567685
# Epoch 3800
# Mean training error: 0.0602555922
# Epoch 3825
# Mean training error: 0.0602544414
# Epoch 3850
# Mean training error: 0.0602533147
# Epoch 3875
# Mean training error: 0.0602522106
# Epoch 3900
# Mean training error: 0.0602511279
# Epoch 3925
# Mean training error: 0.0602500655
# Epoch 3950
# Mean training error: 0.0602490220
# Epoch 3975
# Mean training error: 0.0602479965
# Epoch 4000
# Mean training error: 0.0602469880
# Epoch 4025
# Mean training error: 0.0602459955
# Epoch 4050
# Mean training error: 0.0602450182
# Epoch 4075
# Mean training error: 0.0602440551
# Epoch 4100
# Mean training error: 0.0602431054
# Epoch 4125
# Mean training error: 0.0602421685
# Epoch 4150
# Mean training error: 0.0602412435
# Epoch 4175
# Mean training error: 0.0602403297
# Epoch 4200
# Mean training error: 0.0602394266
# Epoch 4225
# Mean training error: 0.0602385334
# Epoch 4250
# Mean training error: 0.0602376495
# Epoch 4275
# Mean training error: 0.0602367743
# Epoch 4300
# Mean training error: 0.0602359071
# Epoch 4325
# Mean training error: 0.0602350475
# Epoch 4350
# Mean training error: 0.0602341948
# Epoch 4375
# Mean training error: 0.0602333485
# Epoch 4400
# Mean training error: 0.0602325078
# Epoch 4425
# Mean training error: 0.0602316724
# Epoch 4450
# Mean training error: 0.0602308415
# Epoch 4475
# Mean training error: 0.0602300146
# Epoch 4500
# Mean training error: 0.0602291910
# Epoch 4525
# Mean training error: 0.0602283701
# Epoch 4550
# Mean training error: 0.0602275513
# Epoch 4575
# Mean training error: 0.0602267339
# Epoch 4600
# Mean training error: 0.0602259171
# Epoch 4625
# Mean training error: 0.0602251003
# Epoch 4650
# Mean training error: 0.0602242827
# Epoch 4675
# Mean training error: 0.0602234634
# Epoch 4700
# Mean training error: 0.0602226417
# Epoch 4725
# Mean training error: 0.0602218166
# Epoch 4750
# Mean training error: 0.0602209871
# Epoch 4775
# Mean training error: 0.0602201521
# Epoch 4800
# Mean training error: 0.0602193106
# Epoch 4825
# Mean training error: 0.0602184613
# Epoch 4850
# Mean training error: 0.0602176028
# Epoch 4875
# Mean training error: 0.0602167336
# Epoch 4900
# Mean training error: 0.0602158521
# Epoch 4925
# Mean training error: 0.0602149564
# Epoch 4950
# Mean training error: 0.0602140444
# Epoch 4975
# Mean training error: 0.0602131138
# Epoch 5000
# Mean training error: 0.0602121619
# Final training error after 5000 epochs: 0.0602121619; lowest error: 0.0602121619
# Last mean error: 0.0602275279

# %%
# similarity encoder with similarities relying on class information - 2 hidden layers
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [20, 10], 
                              [T.tanh, T.tanh, None, scaled_sigmoid], lrate=10., 
                              L2_reg=0.000005)
e_csimenc.fit(X, S, verbose=True)
X_embed = e_csimenc.transform(X)
plot_digits(X_embed, digits, title='Digits - SimEc (class sim, 2 h.l.)', plot_box=False)
# Out:
# Epoch 1
# Mean training error: 0.0987195958
# Epoch 25
# Mean training error: 0.0960048065
# Epoch 50
# Mean training error: 0.0896424517
# Epoch 75
# Mean training error: 0.0514848990
# Epoch 100
# Mean training error: 0.0448533969
# Epoch 125
# Mean training error: 0.0399458256
# Epoch 150
# Mean training error: 0.0325073813
# Epoch 175
# Mean training error: 0.0286732701
# Epoch 200
# Mean training error: 0.0272229916
# Epoch 225
# Mean training error: 0.0257381324
# Epoch 250
# Mean training error: 0.0242110714
# Epoch 275
# Mean training error: 0.0222542520
# Epoch 300
# Mean training error: 0.0201765082
# Epoch 325
# Mean training error: 0.0195656646
# Epoch 350
# Mean training error: 0.0191638564
# Epoch 375
# Mean training error: 0.0187844146
# Epoch 400
# Mean training error: 0.0202506746
# Learning rate too high! Reseting to best local minima (error: 0.0187820362).
# Sanity check, mean test error: 0.0190508035
# Epoch 425
# Mean training error: 0.0193883715
# Learning rate too high! Reseting to best local minima (error: 0.0186134726).
# Sanity check, mean test error: 0.0188660260
# Epoch 450
# Mean training error: 0.0183814076
# Epoch 475
# Mean training error: 0.0182113903
# Epoch 500
# Mean training error: 0.0179955059
# Epoch 525
# Mean training error: 0.0178777977
# Learning rate too high! Reseting to best local minima (error: 0.0175718984).
# Sanity check, mean test error: 0.0175463350
# Epoch 550
# Mean training error: 0.0200299277
# Learning rate too high! Reseting to best local minima (error: 0.0152325331).
# Sanity check, mean test error: 0.0151896783
# Epoch 575
# Mean training error: 0.0132568687
# Epoch 600
# Mean training error: 0.0126245551
# Epoch 625
# Mean training error: 0.0122484391
# Epoch 650
# Mean training error: 0.0119814304
# Epoch 675
# Mean training error: 0.0117982750
# Epoch 700
# Mean training error: 0.0116523856
# Epoch 725
# Mean training error: 0.0115341710
# Epoch 750
# Mean training error: 0.0114300387
# Epoch 775
# Mean training error: 0.0113426659
# Epoch 800
# Mean training error: 0.0112642396
# Epoch 825
# Mean training error: 0.0111941287
# Epoch 850
# Mean training error: 0.0111713082
# Learning rate too high! Reseting to best local minima (error: 0.0111570160).
# Sanity check, mean test error: 0.0111559723
# Epoch 875
# Mean training error: 0.0110937489
# Epoch 900
# Mean training error: 0.0110469174
# Epoch 925
# Mean training error: 0.0110041513
# Epoch 950
# Mean training error: 0.0109660742
# Epoch 975
# Mean training error: 0.0109308550
# Epoch 1000
# Mean training error: 0.0108979144
# Epoch 1025
# Mean training error: 0.0108667256
# Epoch 1050
# Mean training error: 0.0108367199
# Epoch 1075
# Mean training error: 0.0108072053
# Epoch 1100
# Mean training error: 0.0107771303
# Epoch 1125
# Mean training error: 0.0107431141
# Epoch 1150
# Mean training error: 0.0106806860
# Epoch 1175
# Mean training error: 0.0106355838
# Epoch 1200
# Mean training error: 0.0105964618
# Epoch 1225
# Mean training error: 0.0105618060
# Epoch 1250
# Mean training error: 0.0105302077
# Epoch 1275
# Mean training error: 0.0105008817
# Epoch 1300
# Mean training error: 0.0104734365
# Epoch 1325
# Mean training error: 0.0104476412
# Epoch 1350
# Mean training error: 0.0104233305
# Epoch 1375
# Mean training error: 0.0104003659
# Epoch 1400
# Mean training error: 0.0103786192
# Epoch 1425
# Mean training error: 0.0103579685
# Epoch 1450
# Mean training error: 0.0103382994
# Epoch 1475
# Mean training error: 0.0103195068
# Epoch 1500
# Mean training error: 0.0103014966
# Epoch 1525
# Mean training error: 0.0102841850
# Epoch 1550
# Mean training error: 0.0102674972
# Epoch 1575
# Mean training error: 0.0102513636
# Epoch 1600
# Mean training error: 0.0102357128
# Epoch 1625
# Mean training error: 0.0102204432
# Epoch 1650
# Mean training error: 0.0102052265
# Epoch 1675
# Mean training error: 0.0101637069
# Epoch 1700
# Mean training error: 0.0101334741
# Epoch 1725
# Mean training error: 0.0101166091
# Epoch 1750
# Mean training error: 0.0101015196
# Epoch 1775
# Mean training error: 0.0100873316
# Epoch 1800
# Mean training error: 0.0100737191
# Epoch 1825
# Mean training error: 0.0100605123
# Epoch 1850
# Mean training error: 0.0100476033
# Epoch 1875
# Mean training error: 0.0100349128
# Epoch 1900
# Mean training error: 0.0100223755
# Epoch 1925
# Mean training error: 0.0100099322
# Epoch 1950
# Mean training error: 0.0099975255
# Epoch 1975
# Mean training error: 0.0099850958
# Epoch 2000
# Mean training error: 0.0099725788
# Epoch 2025
# Mean training error: 0.0099599023
# Epoch 2050
# Mean training error: 0.0099469837
# Epoch 2075
# Mean training error: 0.0099337275
# Epoch 2100
# Mean training error: 0.0099200251
# Epoch 2125
# Mean training error: 0.0099057579
# Epoch 2150
# Mean training error: 0.0098908066
# Epoch 2175
# Mean training error: 0.0098750636
# Epoch 2200
# Mean training error: 0.0098584239
# Epoch 2225
# Mean training error: 0.0098406812
# Epoch 2250
# Mean training error: 0.0098212420
# Epoch 2275
# Mean training error: 0.0098065852
# Epoch 2300
# Mean training error: 0.0100759142
# Learning rate too high! Reseting to best local minima (error: 0.0097798752).
# Sanity check, mean test error: 0.0097086121
# Epoch 2325
# Mean training error: 0.0096997776
# Epoch 2350
# Mean training error: 0.0096875980
# Learning rate too high! Reseting to best local minima (error: 0.0096567891).
# Sanity check, mean test error: 0.0096066918
# Epoch 2375
# Mean training error: 0.0095440174
# Epoch 2400
# Mean training error: 0.0095070803
# Epoch 2425
# Mean training error: 0.0094347034
# Learning rate too high! Reseting to best local minima (error: 0.0094203287).
# Sanity check, mean test error: 0.0093595678
# Epoch 2450
# Mean training error: 0.0092657713
# Epoch 2475
# Mean training error: 0.0092421769
# Learning rate too high! Reseting to best local minima (error: 0.0091801249).
# Sanity check, mean test error: 0.0091335142
# Epoch 2500
# Mean training error: 0.0090618180
# Epoch 2525
# Mean training error: 0.0089573427
# Epoch 2550
# Mean training error: 0.0088416773
# Epoch 2575
# Mean training error: 0.0087143820
# Epoch 2600
# Mean training error: 0.0085761734
# Epoch 2625
# Mean training error: 0.0084281066
# Epoch 2650
# Mean training error: 0.0082714831
# Epoch 2675
# Mean training error: 0.0081077587
# Epoch 2700
# Mean training error: 0.0079489591
# Epoch 2725
# Mean training error: 0.0077906643
# Epoch 2750
# Mean training error: 0.0077015666
# Learning rate too high! Reseting to best local minima (error: 0.0076155364).
# Sanity check, mean test error: 0.0075694052
# Epoch 2775
# Mean training error: 0.0074471878
# Epoch 2800
# Mean training error: 0.0073153607
# Epoch 2825
# Mean training error: 0.0071861108
# Epoch 2850
# Mean training error: 0.0070593637
# Epoch 2875
# Mean training error: 0.0069353015
# Epoch 2900
# Mean training error: 0.0068141160
# Epoch 2925
# Mean training error: 0.0066959674
# Epoch 2950
# Mean training error: 0.0065809772
# Epoch 2975
# Mean training error: 0.0064692313
# Epoch 3000
# Mean training error: 0.0063607843
# Epoch 3025
# Mean training error: 0.0062556659
# Epoch 3050
# Mean training error: 0.0061538855
# Epoch 3075
# Mean training error: 0.0060554300
# Epoch 3100
# Mean training error: 0.0059602552
# Epoch 3125
# Mean training error: 0.0058682828
# Epoch 3150
# Mean training error: 0.0057794159
# Epoch 3175
# Mean training error: 0.0056935482
# Epoch 3200
# Mean training error: 0.0056105643
# Epoch 3225
# Mean training error: 0.0055303418
# Epoch 3250
# Mean training error: 0.0054527543
# Epoch 3275
# Mean training error: 0.0053776755
# Epoch 3300
# Mean training error: 0.0053049815
# Epoch 3325
# Mean training error: 0.0052345539
# Epoch 3350
# Mean training error: 0.0051662808
# Epoch 3375
# Mean training error: 0.0051000588
# Epoch 3400
# Mean training error: 0.0050357941
# Epoch 3425
# Mean training error: 0.0049734032
# Epoch 3450
# Mean training error: 0.0049128149
# Epoch 3475
# Mean training error: 0.0048539702
# Epoch 3500
# Mean training error: 0.0047968230
# Epoch 3525
# Mean training error: 0.0047413391
# Epoch 3550
# Mean training error: 0.0046874940
# Epoch 3575
# Mean training error: 0.0046352707
# Epoch 3600
# Mean training error: 0.0045846552
# Epoch 3625
# Mean training error: 0.0045356329
# Epoch 3650
# Mean training error: 0.0044881852
# Epoch 3675
# Mean training error: 0.0044422876
# Epoch 3700
# Mean training error: 0.0043979081
# Epoch 3725
# Mean training error: 0.0043550077
# Epoch 3750
# Mean training error: 0.0043135417
# Epoch 3775
# Mean training error: 0.0042734606
# Epoch 3800
# Mean training error: 0.0042347120
# Epoch 3825
# Mean training error: 0.0041972418
# Epoch 3850
# Mean training error: 0.0041609958
# Epoch 3875
# Mean training error: 0.0041259200
# Epoch 3900
# Mean training error: 0.0040919620
# Epoch 3925
# Mean training error: 0.0040590708
# Epoch 3950
# Mean training error: 0.0040271976
# Epoch 3975
# Mean training error: 0.0039962955
# Epoch 4000
# Mean training error: 0.0039663199
# Epoch 4025
# Mean training error: 0.0039372283
# Epoch 4050
# Mean training error: 0.0039089801
# Epoch 4075
# Mean training error: 0.0038815369
# Epoch 4100
# Mean training error: 0.0038548616
# Epoch 4125
# Mean training error: 0.0038289191
# Epoch 4150
# Mean training error: 0.0038036755
# Epoch 4175
# Mean training error: 0.0037790983
# Epoch 4200
# Mean training error: 0.0037551561
# Epoch 4225
# Mean training error: 0.0037318181
# Epoch 4250
# Mean training error: 0.0037090547
# Epoch 4275
# Mean training error: 0.0036868365
# Epoch 4300
# Mean training error: 0.0036651341
# Epoch 4325
# Mean training error: 0.0036439183
# Epoch 4350
# Mean training error: 0.0036231590
# Epoch 4375
# Mean training error: 0.0036028250
# Epoch 4400
# Mean training error: 0.0035828833
# Epoch 4425
# Mean training error: 0.0035632977
# Epoch 4450
# Mean training error: 0.0035440280
# Epoch 4475
# Mean training error: 0.0035250280
# Epoch 4500
# Mean training error: 0.0035062438
# Epoch 4525
# Mean training error: 0.0034876119
# Epoch 4550
# Mean training error: 0.0034690596
# Epoch 4575
# Mean training error: 0.0034505108
# Epoch 4600
# Mean training error: 0.0034319022
# Epoch 4625
# Mean training error: 0.0034132140
# Epoch 4650
# Mean training error: 0.0033945020
# Epoch 4675
# Mean training error: 0.0033758988
# Epoch 4700
# Mean training error: 0.0033575649
# Epoch 4725
# Mean training error: 0.0033396243
# Epoch 4750
# Mean training error: 0.0033221358
# Epoch 4775
# Mean training error: 0.0033051042
# Epoch 4800
# Mean training error: 0.0032885056
# Epoch 4825
# Mean training error: 0.0032723061
# Epoch 4850
# Mean training error: 0.0032564713
# Epoch 4875
# Mean training error: 0.0032409708
# Epoch 4900
# Mean training error: 0.0032257785
# Epoch 4925
# Mean training error: 0.0032108724
# Epoch 4950
# Mean training error: 0.0031962342
# Epoch 4975
# Mean training error: 0.0031818487
# Epoch 5000
# Mean training error: 0.0031677028
# Final training error after 5000 epochs: 0.0031677028; lowest error: 0.0031677028
# Last mean error: 0.0031627339

# %% [markdown]
# You can also play around with other error functions, like cross-entropy or kl-divergence, sometimes these give good results as well.

# %%
# similarity encoder with similarities relying on class information - linear
# thresholding on the output, optimize cross-entropy
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [100], [T.tanh, None, scaled_sigmoid],
                              lrate=5., orthOT_reg=0.05, error_fun='cross-entropy')
e_csimenc.fit(X, S, verbose=False)
X_embed = e_csimenc.transform(X)
plot_digits(X_embed, digits, 
            title='Digits - SimEc (class sim, 1 h.l.; cross-entropy)')
# Out:
# Final training error: 0.0704769041; lowest error: 0.0704769041
# Last mean error: 0.0704646959

# %% [markdown]
# With a target similarity matrix based on class membership the SimEc nicely clusters data points belonging to the same class. Just for comparison, let's see how this looks like if we use a network optimized for the corresponding classification task, but where we use only two neurons in the second to last layer and visualize the embeddings of this.

# %%
model = SupervisedNNModel(X.shape[1], 10, hunits=[100, 2], 
                          activations=[T.tanh, T.tanh, T.nnet.softmax], 
                          cost_fun='negative_log_likelihood',
                          error_fun='zero_one_loss', learning_rate=0.01, 
                          L1_reg=0., L2_reg=0.0001)
model.fit(X, y, verbose=False)
# plot embedding
X_embed = model.transform(X)
plot_digits(X_embed, digits, title='Digits - Supervised NN activations', plot_box=False)
# Out:
# Final training error: 0.066307

# %% [markdown]
# ## MNIST Dataset
# Embedding the regular 28x28 pixel MNIST digits

# %%
# load digits
mnist = fetch_mldata('MNIST original', data_home='data')
X = mnist.data/255.  # normalize to 0-1
y = np.array(mnist.target, dtype=int)
# subsample 10000 random data points
np.random.seed(42)
n_samples = 10000
n_test = 2000
rnd_idx = np.random.permutation(X.shape[0])[:n_samples]
X_test, y_test = X[rnd_idx[:n_test],:], y[rnd_idx[:n_test]]
X, y = X[rnd_idx[n_test:],:], y[rnd_idx[n_test:]]
n_train, n_features = X.shape

# %% [markdown]
# #### Linear SimEc
# Linear SimEc again gives the same solution as PCA/linear kPCA.

# %%
# linear kPCA
e_lkpca = KernelPCA(n_components=2, kernel='linear')
X_embed = e_lkpca.fit_transform(X)
X_embed_test = e_lkpca.transform(X_test)
plot_mnist(X_embed, y, X_embed_test, y_test, title='MNIST - linear Kernel PCA')

# %%
# linear similarity encoder (center the kernel matrix first!)
K_lin = np.dot(X, X.T)
e_lsimenc = SimilarityEncoder(K_lin.shape[1], X.shape[1], e_dim=2, lrate=1., orthOT_reg=0.1)
e_lsimenc.fit(X, center_K(K_lin), verbose=False)
X_embeds = e_lsimenc.transform(X)
X_embed_tests = e_lsimenc.transform(X_test)
plot_mnist(X_embeds, y, X_embed_tests, y_test, title='MNIST - SimEc (lin. kernel, linear)')
print "correlation with lin kPCA: %f" % check_embed_match(X_embed, X_embeds)
print "correlation with lin kPCA (test): %f" % check_embed_match(X_embed_test, X_embed_tests)
# Out:
# Final training error: 0.0034702930; lowest error: 0.0034702930
# Last mean error: 0.0034702195
# correlation with lin kPCA: 0.958719
# correlation with lin kPCA (test): 0.960073

# %% [markdown]
# #### Non-linear SimEc
# Isomap and corresponding SimEc with 2 hidden layers.

# %%
# isomap
e_isomap = Isomap(n_neighbors=10, n_components=2)
X_embed = e_isomap.fit_transform(X)
X_embed_test = e_isomap.transform(X_test)
plot_mnist(X_embed, y, X_embed_test, y_test, title='MNIST - isomap')

# %%
# non-linear SimEc to approximate isomap solution
K_geod = e_isomap.dist_matrix_
e_gsimenc = SimilarityEncoder(K_geod.shape[1], X.shape[1], 2, [100, 20], 
                              [T.nnet.relu, T.nnet.relu, None, None], lrate=2., orthOT_reg=0.02)
e_gsimenc.fit(X, center_K(K_geod), verbose=False)
X_embeds = e_gsimenc.transform(X)
X_embed_tests = e_gsimenc.transform(X_test)
plot_mnist(X_embeds, y, X_embed_tests, y_test, title='MNIST - SimEc (isomap, 2 h.l.)')
print "correlation with isomap: %f" % check_embed_match(X_embed, X_embeds)
print "correlation with isomap (test): %f" % check_embed_match(X_embed_test, X_embed_tests)
# Out:
# Final training error: 0.0079275022; lowest error: 0.0079275022
# Last mean error: 0.0079273632
# correlation with isomap: 0.917331
# correlation with isomap (test): 0.894935

# %% [markdown]
# #### Supervised SimEc
# Try SimEcs with a varying number of non-linear hidden layers to approximate class-based similarities in the embedding.

# %%
# similarity encoder with similarities relying on class information - linear
Y = np.tile(y, (len(y), 1))
S = np.array(Y==Y.T, dtype=int)
# we again use thresholding on the output
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [], [None, scaled_sigmoid],
                              orthOT_reg=0.02, lrate=1., lrate_decay=1.)
e_csimenc.fit(X, S, verbose=False)
X_embed = e_csimenc.transform(X)
X_embed_test = e_csimenc.transform(X_test)
plot_mnist(X_embed, y, X_embed_test, y_test, title='MNIST - SimEc (class sim, linear)')
# Out:
# Final training error: 0.0537350187; lowest error: 0.0537350187
# Last mean error: 0.0536981731

# %%
# class labels - 1 hidden layer
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [100], [T.tanh, None, scaled_sigmoid],
                              orthOT_reg=0.02, lrate=1., lrate_decay=1.)
e_csimenc.fit(X, S, verbose=False)
X_embed = e_csimenc.transform(X)
X_embed_test = e_csimenc.transform(X_test)
plot_mnist(X_embed, y, X_embed_test, y_test, title='MNIST - SimEc (class sim, 1 h.l.)')
# Out:
# Final training error: 0.0268853535; lowest error: 0.0268843970
# Last mean error: 0.0268547307

# %%
# class labels - 2 hidden layers
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [100, 50],
                              [T.tanh, T.tanh, None, scaled_sigmoid], orthOT_reg=0.02,
                              lrate=1., lrate_decay=1.)
e_csimenc.fit(X, S, verbose=False)
X_embed = e_csimenc.transform(X)
X_embed_test = e_csimenc.transform(X_test)
plot_mnist(X_embed, y, X_embed_test, y_test, title='MNIST - SimEc (class sim, 2 h.l.)')
# Out:
# Final training error: 0.0101834877; lowest error: 0.0101834877
# Last mean error: 0.0101591847

# %%
# class labels - 3 hidden layers
e_csimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [100, 50, 30],
                              [T.tanh, T.tanh, T.tanh, None, scaled_sigmoid], orthOT_reg=0.02,
                              lrate=1., lrate_decay=1.)
e_csimenc.fit(X, S, verbose=False)
X_embed = e_csimenc.transform(X)
X_embed_test = e_csimenc.transform(X_test)
plot_mnist(X_embed, y, X_embed_test, y_test, title='MNIST - SimEc (class sim, 3 h.l.)')
# Out:
# Final training error: 0.0104404734; lowest error: 0.0104397192
# Last mean error: 0.0104237267

# %% [markdown]
# ## 20 Newsgroups
# To show that SimEc embeddings can also be computed for other types of data, we do some further experiments with the 20 newsgroups dataset. We subsample 7 of the 20 categories and remove meta information such as headers to avoid overfitting (see also `http://scikit-learn.org/stable/datasets/twenty_newsgroups.html`). The posts are transformed into very high dimensional tf-idf vectors used as input to the SimEc and to compute the linear kernel matrix.

# %%
## load the data and transform it into a tf-idf representation
categories = [
    "comp.graphics",
    "rec.autos",
    "rec.sport.baseball",
    "sci.med",
    "sci.space",
    "soc.religion.christian",
    "talk.politics.guns"
]
newsgroups_train = fetch_20newsgroups(subset='train', remove=(
    'headers', 'footers', 'quotes'), data_home='data', categories=categories, random_state=42)
newsgroups_test = fetch_20newsgroups(subset='test', remove=(
    'headers', 'footers', 'quotes'), data_home='data', categories=categories, random_state=42)
# store in dicts (if the text contains more than 3 words)
textdict = {i: t for i, t in enumerate(newsgroups_train.data) if len(t.split()) > 3}
textdict.update({i: t for i, t in enumerate(newsgroups_test.data, len(newsgroups_train.data)) if len(t.split()) > 3})
train_ids = [i for i in range(len(newsgroups_train.data)) if i in textdict]
test_ids = [i for i in range(len(newsgroups_train.data), len(textdict)) if i in textdict]
print "%i training and %i test samples" % (len(train_ids), len(test_ids))
# transform into tf-idf features
ft = FeatureTransform(norm='max', weight=True, renorm='max')
docfeats = ft.texts2features(textdict, fit_ids=train_ids)
# organize in feature matrix
X, featurenames = features2mat(docfeats, train_ids)
X_test, _ = features2mat(docfeats, test_ids, featurenames)
print "%i features" % len(featurenames)
targets = np.hstack([newsgroups_train.target,newsgroups_test.target])
y = targets[train_ids]
y_test = targets[test_ids]
target_names = newsgroups_train.target_names
# Out:
# 3959 training and 2359 test samples
# 45813 features

# %% [markdown]
# #### Linear SimEc
# Again, linear kPCA and SimEc give the same solution (up to a rotation). Btw, here we can't use regular PCA as the covariance matrix would be very high dimensional and poorly estimated due to the small amount of samples.

# %%
# linear kPCA
e_lkpca = KernelPCA(n_components=2, kernel='linear')
X_embed = e_lkpca.fit_transform(X)
X_embed_test = e_lkpca.transform(X_test)
plot_20news(X_embed, y, target_names, X_embed_test, y_test,
            title='20newsgroups - linear Kernel PCA', legend=True)

# %%
# compute linear kernel and center
K = X.dot(X.T).A
K_cent = center_K(K)
# project to 2d with linear similarity encoder
e_lsimenc = SimilarityEncoder(K_cent.shape[1], X.shape[1], 2, [], [None, None],
                              sparse_features=True, lrate=100., orthOT_reg=0.00025)
e_lsimenc.fit(X, K_cent, verbose=False)
X_embeds = e_lsimenc.transform(X)
X_embed_tests = e_lsimenc.transform(X_test)
plot_20news(X_embeds, y, target_names, X_embed_tests, y_test,
            title='20 newsgroups - SimEc (lin. kernel, linear)')
print "correlation with lin kPCA: %f" % check_embed_match(X_embed, X_embeds)
print "correlation with lin kPCA (test): %f" % check_embed_match(X_embed_test, X_embed_tests)
# Out:
# Final training error: 0.0000180320; lowest error: 0.0000180320
# Last mean error: 0.0000180307
# correlation with lin kPCA: 0.964823
# correlation with lin kPCA (test): 0.964971

# %% [markdown]
# #### Supervised SimEc
# Non-linear SimEc to create a 2d embedding in which the class-based similarities are retained. (Btw, the scaled sigmoid also works well as an activation function for earlier hidden layers.)

# %%
# compute label based simmat
Y = np.tile(y, (len(y), 1))
S = np.array(Y==Y.T, dtype=int)
# project to 2d with similarity encoder
e_lsimenc = SimilarityEncoder(S.shape[1], X.shape[1], 2, [100],
                              [scaled_sigmoid, None, scaled_sigmoid], sparse_features=True,
                              orthOT_reg=0.00025, lrate=15., lrate_decay=1.)
e_lsimenc.fit(X, S, verbose=False)
X_embed = e_lsimenc.transform(X)
X_embed_test = e_lsimenc.transform(X_test)
plot_20news(X_embed, y, target_names, X_embed_test, y_test,
            title='20 newsgroups - SimEc (class sim, 1 h.l.)')
# Out:
# Final training error: 0.0001132594; lowest error: 0.0001132594
# Last mean error: 0.0001132580
